# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
 # %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
 import tensorflow as tf
 print(tf.__version__)

 import os
 from google.colab import drive 
 drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
 # %cd 'gdrive/My Drive'
 os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
 # %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.0
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# [Errno 2] No such file or directory: 'cupoy_cv_part4 # 可以自己改路徑'
# /content/gdrive/My Drive

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0079 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00236, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0021 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00236 to 0.00189, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00189
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00189 to 0.00187, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00187
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00187 to 0.00180, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7597e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00180 to 0.00176, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.6944e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00176 to 0.00169, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.5538e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00169 to 0.00147, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.3593e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00147 to 0.00139, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.9234e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00139 to 0.00119, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.3806e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00119 to 0.00116, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0494e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00116 to 0.00112, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.7417e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00112 to 0.00104, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4926e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00104
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.3332e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00104 to 0.00102, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0634e-04 - val_loss: 9.8223e-04
#
# Epoch 00017: val_loss improved from 0.00102 to 0.00098, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.8828e-04 - val_loss: 9.6259e-04
#
# Epoch 00018: val_loss improved from 0.00098 to 0.00096, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7313e-04 - val_loss: 9.4259e-04
#
# Epoch 00019: val_loss improved from 0.00096 to 0.00094, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6003e-04 - val_loss: 9.2082e-04
#
# Epoch 00020: val_loss improved from 0.00094 to 0.00092, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4035e-04 - val_loss: 9.1748e-04
#
# Epoch 00021: val_loss improved from 0.00092 to 0.00092, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3072e-04 - val_loss: 9.3596e-04
#
# Epoch 00022: val_loss did not improve from 0.00092
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1870e-04 - val_loss: 9.1035e-04
#
# Epoch 00023: val_loss improved from 0.00092 to 0.00091, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1707e-04 - val_loss: 9.0737e-04
#
# Epoch 00024: val_loss improved from 0.00091 to 0.00091, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0425e-04 - val_loss: 9.1646e-04
#
# Epoch 00025: val_loss did not improve from 0.00091
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9398e-04 - val_loss: 9.2409e-04
#
# Epoch 00026: val_loss did not improve from 0.00091
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9010e-04 - val_loss: 8.7628e-04
#
# Epoch 00027: val_loss improved from 0.00091 to 0.00088, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7569e-04 - val_loss: 8.6192e-04
#
# Epoch 00028: val_loss improved from 0.00088 to 0.00086, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7040e-04 - val_loss: 8.7367e-04
#
# Epoch 00029: val_loss did not improve from 0.00086
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6335e-04 - val_loss: 8.6782e-04
#
# Epoch 00030: val_loss did not improve from 0.00086
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6556e-04 - val_loss: 8.7617e-04
#
# Epoch 00031: val_loss did not improve from 0.00086
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5072e-04 - val_loss: 8.8057e-04
#
# Epoch 00032: val_loss did not improve from 0.00086
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4956e-04 - val_loss: 8.5869e-04
#
# Epoch 00033: val_loss improved from 0.00086 to 0.00086, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4919e-04 - val_loss: 8.5521e-04
#
# Epoch 00034: val_loss improved from 0.00086 to 0.00086, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4015e-04 - val_loss: 9.1453e-04
#
# Epoch 00035: val_loss did not improve from 0.00086
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3779e-04 - val_loss: 9.0287e-04
#
# Epoch 00036: val_loss did not improve from 0.00086
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2950e-04 - val_loss: 8.4602e-04
#
# Epoch 00037: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3455e-04 - val_loss: 9.3184e-04
#
# Epoch 00038: val_loss did not improve from 0.00085
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2632e-04 - val_loss: 8.4740e-04
#
# Epoch 00039: val_loss did not improve from 0.00085
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2459e-04 - val_loss: 8.5284e-04
#
# Epoch 00040: val_loss did not improve from 0.00085
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1448e-04 - val_loss: 8.5223e-04
#
# Epoch 00041: val_loss did not improve from 0.00085
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1119e-04 - val_loss: 8.6441e-04
#
# Epoch 00042: val_loss did not improve from 0.00085
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1313e-04 - val_loss: 8.3018e-04
#
# Epoch 00043: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0697e-04 - val_loss: 8.3172e-04
#
# Epoch 00044: val_loss did not improve from 0.00083
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0850e-04 - val_loss: 8.3366e-04
#
# Epoch 00045: val_loss did not improve from 0.00083
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0668e-04 - val_loss: 8.2714e-04
#
# Epoch 00046: val_loss improved from 0.00083 to 0.00083, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0231e-04 - val_loss: 8.1986e-04
#
# Epoch 00047: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0222e-04 - val_loss: 8.2354e-04
#
# Epoch 00048: val_loss did not improve from 0.00082
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9624e-04 - val_loss: 8.2647e-04
#
# Epoch 00049: val_loss did not improve from 0.00082
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9306e-04 - val_loss: 8.0908e-04
#
# Epoch 00050: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9272e-04 - val_loss: 8.0785e-04
#
# Epoch 00051: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9010e-04 - val_loss: 8.3076e-04
#
# Epoch 00052: val_loss did not improve from 0.00081
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8655e-04 - val_loss: 8.1797e-04
#
# Epoch 00053: val_loss did not improve from 0.00081
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8630e-04 - val_loss: 8.1163e-04
#
# Epoch 00054: val_loss did not improve from 0.00081
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8762e-04 - val_loss: 8.0435e-04
#
# Epoch 00055: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7429e-04 - val_loss: 8.0426e-04
#
# Epoch 00056: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8233e-04 - val_loss: 8.2469e-04
#
# Epoch 00057: val_loss did not improve from 0.00080
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7391e-04 - val_loss: 8.2360e-04
#
# Epoch 00058: val_loss did not improve from 0.00080
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7933e-04 - val_loss: 7.8791e-04
#
# Epoch 00059: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7511e-04 - val_loss: 8.0822e-04
#
# Epoch 00060: val_loss did not improve from 0.00079
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7096e-04 - val_loss: 8.4642e-04
#
# Epoch 00061: val_loss did not improve from 0.00079
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6766e-04 - val_loss: 8.2266e-04
#
# Epoch 00062: val_loss did not improve from 0.00079
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7016e-04 - val_loss: 8.0663e-04
#
# Epoch 00063: val_loss did not improve from 0.00079
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6802e-04 - val_loss: 8.4131e-04
#
# Epoch 00064: val_loss did not improve from 0.00079
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6566e-04 - val_loss: 8.1658e-04
#
# Epoch 00065: val_loss did not improve from 0.00079
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5890e-04 - val_loss: 8.5906e-04
#
# Epoch 00066: val_loss did not improve from 0.00079
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6060e-04 - val_loss: 8.5354e-04
#
# Epoch 00067: val_loss did not improve from 0.00079
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5949e-04 - val_loss: 8.5035e-04
#
# Epoch 00068: val_loss did not improve from 0.00079
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5752e-04 - val_loss: 8.0969e-04
#
# Epoch 00069: val_loss did not improve from 0.00079
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5804e-04 - val_loss: 8.3225e-04
#
# Epoch 00070: val_loss did not improve from 0.00079
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5349e-04 - val_loss: 8.3756e-04
#
# Epoch 00071: val_loss did not improve from 0.00079
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5409e-04 - val_loss: 9.2604e-04
#
# Epoch 00072: val_loss did not improve from 0.00079
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5992e-04 - val_loss: 8.2326e-04
#
# Epoch 00073: val_loss did not improve from 0.00079
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4991e-04 - val_loss: 8.5127e-04
#
# Epoch 00074: val_loss did not improve from 0.00079
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4435e-04 - val_loss: 8.1862e-04
#
# Epoch 00075: val_loss did not improve from 0.00079
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4429e-04 - val_loss: 8.1715e-04
#
# Epoch 00076: val_loss did not improve from 0.00079
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4446e-04 - val_loss: 8.7229e-04
#
# Epoch 00077: val_loss did not improve from 0.00079
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4756e-04 - val_loss: 8.1594e-04
#
# Epoch 00078: val_loss did not improve from 0.00079
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4303e-04 - val_loss: 7.7705e-04
#
# Epoch 00079: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4181e-04 - val_loss: 7.8321e-04
#
# Epoch 00080: val_loss did not improve from 0.00078
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3918e-04 - val_loss: 8.1236e-04
#
# Epoch 00081: val_loss did not improve from 0.00078
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3878e-04 - val_loss: 8.0510e-04
#
# Epoch 00082: val_loss did not improve from 0.00078
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3455e-04 - val_loss: 7.8710e-04
#
# Epoch 00083: val_loss did not improve from 0.00078
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3509e-04 - val_loss: 7.8060e-04
#
# Epoch 00084: val_loss did not improve from 0.00078
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3078e-04 - val_loss: 8.1460e-04
#
# Epoch 00085: val_loss did not improve from 0.00078
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3061e-04 - val_loss: 7.6682e-04
#
# Epoch 00086: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3206e-04 - val_loss: 8.1203e-04
#
# Epoch 00087: val_loss did not improve from 0.00077
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2899e-04 - val_loss: 8.0152e-04
#
# Epoch 00088: val_loss did not improve from 0.00077
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3065e-04 - val_loss: 8.1740e-04
#
# Epoch 00089: val_loss did not improve from 0.00077
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2655e-04 - val_loss: 8.0493e-04
#
# Epoch 00090: val_loss did not improve from 0.00077
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2716e-04 - val_loss: 8.2024e-04
#
# Epoch 00091: val_loss did not improve from 0.00077
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2396e-04 - val_loss: 7.9367e-04
#
# Epoch 00092: val_loss did not improve from 0.00077
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2972e-04 - val_loss: 8.2587e-04
#
# Epoch 00093: val_loss did not improve from 0.00077
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2819e-04 - val_loss: 7.9190e-04
#
# Epoch 00094: val_loss did not improve from 0.00077
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2428e-04 - val_loss: 8.2041e-04
#
# Epoch 00095: val_loss did not improve from 0.00077
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2159e-04 - val_loss: 7.9378e-04
#
# Epoch 00096: val_loss did not improve from 0.00077
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2445e-04 - val_loss: 8.1293e-04
#
# Epoch 00097: val_loss did not improve from 0.00077
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2274e-04 - val_loss: 8.2000e-04
#
# Epoch 00098: val_loss did not improve from 0.00077
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2012e-04 - val_loss: 7.9313e-04
#
# Epoch 00099: val_loss did not improve from 0.00077
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1592e-04 - val_loss: 8.2856e-04
#
# Epoch 00100: val_loss did not improve from 0.00077
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1869e-04 - val_loss: 8.0626e-04
#
# Epoch 00101: val_loss did not improve from 0.00077
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1746e-04 - val_loss: 8.3194e-04
#
# Epoch 00102: val_loss did not improve from 0.00077
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1873e-04 - val_loss: 8.3375e-04
#
# Epoch 00103: val_loss did not improve from 0.00077
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1754e-04 - val_loss: 7.9364e-04
#
# Epoch 00104: val_loss did not improve from 0.00077
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1297e-04 - val_loss: 8.1635e-04
#
# Epoch 00105: val_loss did not improve from 0.00077
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1137e-04 - val_loss: 8.0135e-04
#
# Epoch 00106: val_loss did not improve from 0.00077
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1239e-04 - val_loss: 7.9605e-04
#
# Epoch 00107: val_loss did not improve from 0.00077
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1167e-04 - val_loss: 8.3129e-04
#
# Epoch 00108: val_loss did not improve from 0.00077
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1406e-04 - val_loss: 8.1267e-04
#
# Epoch 00109: val_loss did not improve from 0.00077
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1215e-04 - val_loss: 7.8969e-04
#
# Epoch 00110: val_loss did not improve from 0.00077
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1182e-04 - val_loss: 8.2160e-04
#
# Epoch 00111: val_loss did not improve from 0.00077
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0845e-04 - val_loss: 8.0656e-04
#
# Epoch 00112: val_loss did not improve from 0.00077
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0810e-04 - val_loss: 8.2274e-04
#
# Epoch 00113: val_loss did not improve from 0.00077
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0759e-04 - val_loss: 8.0730e-04
#
# Epoch 00114: val_loss did not improve from 0.00077
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0911e-04 - val_loss: 8.2810e-04
#
# Epoch 00115: val_loss did not improve from 0.00077
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0527e-04 - val_loss: 8.1779e-04
#
# Epoch 00116: val_loss did not improve from 0.00077
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0443e-04 - val_loss: 8.2247e-04
#
# Epoch 00117: val_loss did not improve from 0.00077
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0686e-04 - val_loss: 8.2763e-04
#
# Epoch 00118: val_loss did not improve from 0.00077
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0673e-04 - val_loss: 8.4378e-04
#
# Epoch 00119: val_loss did not improve from 0.00077
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0362e-04 - val_loss: 8.0872e-04
#
# Epoch 00120: val_loss did not improve from 0.00077
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0324e-04 - val_loss: 8.1673e-04
#
# Epoch 00121: val_loss did not improve from 0.00077
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0647e-04 - val_loss: 8.3263e-04
#
# Epoch 00122: val_loss did not improve from 0.00077
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0497e-04 - val_loss: 7.9623e-04
#
# Epoch 00123: val_loss did not improve from 0.00077
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0196e-04 - val_loss: 8.0634e-04
#
# Epoch 00124: val_loss did not improve from 0.00077
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9679e-05 - val_loss: 8.2072e-04
#
# Epoch 00125: val_loss did not improve from 0.00077
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0474e-04 - val_loss: 8.0312e-04
#
# Epoch 00126: val_loss did not improve from 0.00077
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9483e-05 - val_loss: 8.1370e-04
#
# Epoch 00127: val_loss did not improve from 0.00077
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7659e-05 - val_loss: 8.2138e-04
#
# Epoch 00128: val_loss did not improve from 0.00077
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6062e-05 - val_loss: 7.8320e-04
#
# Epoch 00129: val_loss did not improve from 0.00077
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5442e-05 - val_loss: 7.8342e-04
#
# Epoch 00130: val_loss did not improve from 0.00077
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3951e-05 - val_loss: 8.3209e-04
#
# Epoch 00131: val_loss did not improve from 0.00077
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5922e-05 - val_loss: 8.2552e-04
#
# Epoch 00132: val_loss did not improve from 0.00077
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8190e-05 - val_loss: 8.1265e-04
#
# Epoch 00133: val_loss did not improve from 0.00077
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3236e-05 - val_loss: 7.9546e-04
#
# Epoch 00134: val_loss did not improve from 0.00077
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6640e-05 - val_loss: 8.0089e-04
#
# Epoch 00135: val_loss did not improve from 0.00077
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6742e-05 - val_loss: 8.1987e-04
#
# Epoch 00136: val_loss did not improve from 0.00077
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5527e-05 - val_loss: 8.1080e-04
#
# Epoch 00137: val_loss did not improve from 0.00077
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1945e-05 - val_loss: 8.0242e-04
#
# Epoch 00138: val_loss did not improve from 0.00077
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3864e-05 - val_loss: 8.1742e-04
#
# Epoch 00139: val_loss did not improve from 0.00077
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2009e-05 - val_loss: 8.0489e-04
#
# Epoch 00140: val_loss did not improve from 0.00077
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3246e-05 - val_loss: 7.9872e-04
#
# Epoch 00141: val_loss did not improve from 0.00077
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1934e-05 - val_loss: 7.9503e-04
#
# Epoch 00142: val_loss did not improve from 0.00077
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9784e-05 - val_loss: 8.2005e-04
#
# Epoch 00143: val_loss did not improve from 0.00077
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0116e-05 - val_loss: 7.8781e-04
#
# Epoch 00144: val_loss did not improve from 0.00077
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0808e-05 - val_loss: 8.0064e-04
#
# Epoch 00145: val_loss did not improve from 0.00077
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8439e-05 - val_loss: 7.7548e-04
#
# Epoch 00146: val_loss did not improve from 0.00077
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0778e-05 - val_loss: 7.8487e-04
#
# Epoch 00147: val_loss did not improve from 0.00077
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9276e-05 - val_loss: 7.9722e-04
#
# Epoch 00148: val_loss did not improve from 0.00077
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8024e-05 - val_loss: 8.2750e-04
#
# Epoch 00149: val_loss did not improve from 0.00077
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0345e-05 - val_loss: 7.9494e-04
#
# Epoch 00150: val_loss did not improve from 0.00077

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
            
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0051 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00198, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00198 to 0.00191, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00191 to 0.00190, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00190 to 0.00184, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9540e-04 - val_loss: 0.0016
#
# Epoch 00005: val_loss improved from 0.00184 to 0.00157, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.9580e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00157 to 0.00121, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.8321e-04 - val_loss: 0.0011
#
# Epoch 00007: val_loss improved from 0.00121 to 0.00109, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.0052e-04 - val_loss: 9.4425e-04
#
# Epoch 00008: val_loss improved from 0.00109 to 0.00094, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.5722e-04 - val_loss: 9.3929e-04
#
# Epoch 00009: val_loss improved from 0.00094 to 0.00094, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.2304e-04 - val_loss: 8.3864e-04
#
# Epoch 00010: val_loss improved from 0.00094 to 0.00084, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.9660e-04 - val_loss: 8.5899e-04
#
# Epoch 00011: val_loss did not improve from 0.00084
# Epoch 12/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.7001e-04 - val_loss: 7.9371e-04
#
# Epoch 00012: val_loss improved from 0.00084 to 0.00079, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.4847e-04 - val_loss: 8.1953e-04
#
# Epoch 00013: val_loss did not improve from 0.00079
# Epoch 14/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.3181e-04 - val_loss: 8.1408e-04
#
# Epoch 00014: val_loss did not improve from 0.00079
# Epoch 15/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.2092e-04 - val_loss: 7.6987e-04
#
# Epoch 00015: val_loss improved from 0.00079 to 0.00077, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.0265e-04 - val_loss: 7.5843e-04
#
# Epoch 00016: val_loss improved from 0.00077 to 0.00076, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.9724e-04 - val_loss: 7.6003e-04
#
# Epoch 00017: val_loss did not improve from 0.00076
# Epoch 18/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.8373e-04 - val_loss: 7.0104e-04
#
# Epoch 00018: val_loss improved from 0.00076 to 0.00070, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.7352e-04 - val_loss: 7.4652e-04
#
# Epoch 00019: val_loss did not improve from 0.00070
# Epoch 20/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.5986e-04 - val_loss: 6.9441e-04
#
# Epoch 00020: val_loss improved from 0.00070 to 0.00069, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.5581e-04 - val_loss: 6.8592e-04
#
# Epoch 00021: val_loss improved from 0.00069 to 0.00069, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.4919e-04 - val_loss: 6.8642e-04
#
# Epoch 00022: val_loss did not improve from 0.00069
# Epoch 23/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.3977e-04 - val_loss: 6.5609e-04
#
# Epoch 00023: val_loss improved from 0.00069 to 0.00066, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3475e-04 - val_loss: 6.8998e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.3130e-04 - val_loss: 6.5796e-04
#
# Epoch 00025: val_loss did not improve from 0.00066
# Epoch 26/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2714e-04 - val_loss: 6.9355e-04
#
# Epoch 00026: val_loss did not improve from 0.00066
# Epoch 27/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.2071e-04 - val_loss: 6.7041e-04
#
# Epoch 00027: val_loss did not improve from 0.00066
# Epoch 28/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.1648e-04 - val_loss: 6.2330e-04
#
# Epoch 00028: val_loss improved from 0.00066 to 0.00062, saving model to best_weights_augment.h5
# Epoch 29/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0738e-04 - val_loss: 6.3454e-04
#
# Epoch 00029: val_loss did not improve from 0.00062
# Epoch 30/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0830e-04 - val_loss: 6.3129e-04
#
# Epoch 00030: val_loss did not improve from 0.00062
# Epoch 31/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0334e-04 - val_loss: 6.5494e-04
#
# Epoch 00031: val_loss did not improve from 0.00062
# Epoch 32/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9959e-04 - val_loss: 6.3621e-04
#
# Epoch 00032: val_loss did not improve from 0.00062
# Epoch 33/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9363e-04 - val_loss: 6.4616e-04
#
# Epoch 00033: val_loss did not improve from 0.00062
# Epoch 34/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8892e-04 - val_loss: 5.9135e-04
#
# Epoch 00034: val_loss improved from 0.00062 to 0.00059, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8808e-04 - val_loss: 6.1714e-04
#
# Epoch 00035: val_loss did not improve from 0.00059
# Epoch 36/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8401e-04 - val_loss: 6.4455e-04
#
# Epoch 00036: val_loss did not improve from 0.00059
# Epoch 37/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8210e-04 - val_loss: 6.1515e-04
#
# Epoch 00037: val_loss did not improve from 0.00059
# Epoch 38/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7729e-04 - val_loss: 6.1059e-04
#
# Epoch 00038: val_loss did not improve from 0.00059
# Epoch 39/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7273e-04 - val_loss: 6.2853e-04
#
# Epoch 00039: val_loss did not improve from 0.00059
# Epoch 40/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6867e-04 - val_loss: 6.3210e-04
#
# Epoch 00040: val_loss did not improve from 0.00059
# Epoch 41/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6830e-04 - val_loss: 6.1289e-04
#
# Epoch 00041: val_loss did not improve from 0.00059
# Epoch 42/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6730e-04 - val_loss: 6.4304e-04
#
# Epoch 00042: val_loss did not improve from 0.00059
# Epoch 43/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6410e-04 - val_loss: 5.8238e-04
#
# Epoch 00043: val_loss improved from 0.00059 to 0.00058, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6316e-04 - val_loss: 5.9469e-04
#
# Epoch 00044: val_loss did not improve from 0.00058
# Epoch 45/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5938e-04 - val_loss: 6.1044e-04
#
# Epoch 00045: val_loss did not improve from 0.00058
# Epoch 46/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6011e-04 - val_loss: 6.1357e-04
#
# Epoch 00046: val_loss did not improve from 0.00058
# Epoch 47/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5728e-04 - val_loss: 6.0615e-04
#
# Epoch 00047: val_loss did not improve from 0.00058
# Epoch 48/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5423e-04 - val_loss: 6.2223e-04
#
# Epoch 00048: val_loss did not improve from 0.00058
# Epoch 49/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5070e-04 - val_loss: 6.0042e-04
#
# Epoch 00049: val_loss did not improve from 0.00058
# Epoch 50/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5265e-04 - val_loss: 6.0775e-04
#
# Epoch 00050: val_loss did not improve from 0.00058
# Epoch 51/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4637e-04 - val_loss: 6.2390e-04
#
# Epoch 00051: val_loss did not improve from 0.00058
# Epoch 52/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4459e-04 - val_loss: 6.1835e-04
#
# Epoch 00052: val_loss did not improve from 0.00058
# Epoch 53/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4578e-04 - val_loss: 5.9433e-04
#
# Epoch 00053: val_loss did not improve from 0.00058
# Epoch 54/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4318e-04 - val_loss: 5.7175e-04
#
# Epoch 00054: val_loss improved from 0.00058 to 0.00057, saving model to best_weights_augment.h5
# Epoch 55/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3920e-04 - val_loss: 6.0987e-04
#
# Epoch 00055: val_loss did not improve from 0.00057
# Epoch 56/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3713e-04 - val_loss: 6.4555e-04
#
# Epoch 00056: val_loss did not improve from 0.00057
# Epoch 57/150
# 3424/3424 [==============================] - 29s 8ms/step - loss: 1.3706e-04 - val_loss: 6.0770e-04
#
# Epoch 00057: val_loss did not improve from 0.00057
# Epoch 58/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3671e-04 - val_loss: 5.7146e-04
#
# Epoch 00058: val_loss improved from 0.00057 to 0.00057, saving model to best_weights_augment.h5
# Epoch 59/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3168e-04 - val_loss: 5.9792e-04
#
# Epoch 00059: val_loss did not improve from 0.00057
# Epoch 60/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3217e-04 - val_loss: 6.3436e-04
#
# Epoch 00060: val_loss did not improve from 0.00057
# Epoch 61/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2796e-04 - val_loss: 5.8777e-04
#
# Epoch 00061: val_loss did not improve from 0.00057
# Epoch 62/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3026e-04 - val_loss: 6.1394e-04
#
# Epoch 00062: val_loss did not improve from 0.00057
# Epoch 63/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2500e-04 - val_loss: 5.8977e-04
#
# Epoch 00063: val_loss did not improve from 0.00057
# Epoch 64/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2581e-04 - val_loss: 6.2377e-04
#
# Epoch 00064: val_loss did not improve from 0.00057
# Epoch 65/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2557e-04 - val_loss: 6.0008e-04
#
# Epoch 00065: val_loss did not improve from 0.00057
# Epoch 66/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2238e-04 - val_loss: 6.0883e-04
#
# Epoch 00066: val_loss did not improve from 0.00057
# Epoch 67/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2189e-04 - val_loss: 5.8711e-04
#
# Epoch 00067: val_loss did not improve from 0.00057
# Epoch 68/150
# 3424/3424 [==============================] - 29s 8ms/step - loss: 1.1739e-04 - val_loss: 6.0339e-04
#
# Epoch 00068: val_loss did not improve from 0.00057
# Epoch 69/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1854e-04 - val_loss: 6.0917e-04
#
# Epoch 00069: val_loss did not improve from 0.00057
# Epoch 70/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1878e-04 - val_loss: 5.8051e-04
#
# Epoch 00070: val_loss did not improve from 0.00057
# Epoch 71/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1743e-04 - val_loss: 6.2332e-04
#
# Epoch 00071: val_loss did not improve from 0.00057
# Epoch 72/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1772e-04 - val_loss: 5.6902e-04
#
# Epoch 00072: val_loss improved from 0.00057 to 0.00057, saving model to best_weights_augment.h5
# Epoch 73/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1537e-04 - val_loss: 5.8694e-04
#
# Epoch 00073: val_loss did not improve from 0.00057
# Epoch 74/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1656e-04 - val_loss: 6.1097e-04
#
# Epoch 00074: val_loss did not improve from 0.00057
# Epoch 75/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1602e-04 - val_loss: 5.9971e-04
#
# Epoch 00075: val_loss did not improve from 0.00057
# Epoch 76/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1264e-04 - val_loss: 6.0731e-04
#
# Epoch 00076: val_loss did not improve from 0.00057
# Epoch 77/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0992e-04 - val_loss: 5.8860e-04
#
# Epoch 00077: val_loss did not improve from 0.00057
# Epoch 78/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1058e-04 - val_loss: 6.0316e-04
#
# Epoch 00078: val_loss did not improve from 0.00057
# Epoch 79/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0983e-04 - val_loss: 5.8545e-04
#
# Epoch 00079: val_loss did not improve from 0.00057
# Epoch 80/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0938e-04 - val_loss: 6.0221e-04
#
# Epoch 00080: val_loss did not improve from 0.00057
# Epoch 81/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0802e-04 - val_loss: 5.9991e-04
#
# Epoch 00081: val_loss did not improve from 0.00057
# Epoch 82/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0986e-04 - val_loss: 5.9062e-04
#
# Epoch 00082: val_loss did not improve from 0.00057
# Epoch 83/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0651e-04 - val_loss: 6.0045e-04
#
# Epoch 00083: val_loss did not improve from 0.00057
# Epoch 84/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0770e-04 - val_loss: 5.8456e-04
#
# Epoch 00084: val_loss did not improve from 0.00057
# Epoch 85/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0681e-04 - val_loss: 6.1040e-04
#
# Epoch 00085: val_loss did not improve from 0.00057
# Epoch 86/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0336e-04 - val_loss: 6.0495e-04
#
# Epoch 00086: val_loss did not improve from 0.00057
# Epoch 87/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0441e-04 - val_loss: 6.0163e-04
#
# Epoch 00087: val_loss did not improve from 0.00057
# Epoch 88/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0292e-04 - val_loss: 6.1475e-04
#
# Epoch 00088: val_loss did not improve from 0.00057
# Epoch 89/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0398e-04 - val_loss: 6.2715e-04
#
# Epoch 00089: val_loss did not improve from 0.00057
# Epoch 90/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0238e-04 - val_loss: 5.8783e-04
#
# Epoch 00090: val_loss did not improve from 0.00057
# Epoch 91/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0241e-04 - val_loss: 6.0026e-04
#
# Epoch 00091: val_loss did not improve from 0.00057
# Epoch 92/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0286e-04 - val_loss: 6.5806e-04
#
# Epoch 00092: val_loss did not improve from 0.00057
# Epoch 93/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0364e-04 - val_loss: 6.1864e-04
#
# Epoch 00093: val_loss did not improve from 0.00057
# Epoch 94/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0167e-04 - val_loss: 6.1904e-04
#
# Epoch 00094: val_loss did not improve from 0.00057
# Epoch 95/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.8789e-05 - val_loss: 6.0668e-04
#
# Epoch 00095: val_loss did not improve from 0.00057
# Epoch 96/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9692e-05 - val_loss: 5.9573e-04
#
# Epoch 00096: val_loss did not improve from 0.00057
# Epoch 97/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9110e-05 - val_loss: 6.0477e-04
#
# Epoch 00097: val_loss did not improve from 0.00057
# Epoch 98/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.8638e-05 - val_loss: 6.3315e-04
#
# Epoch 00098: val_loss did not improve from 0.00057
# Epoch 99/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9438e-05 - val_loss: 6.3792e-04
#
# Epoch 00099: val_loss did not improve from 0.00057
# Epoch 100/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7409e-05 - val_loss: 6.1009e-04
#
# Epoch 00100: val_loss did not improve from 0.00057
# Epoch 101/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.8408e-05 - val_loss: 6.0462e-04
#
# Epoch 00101: val_loss did not improve from 0.00057
# Epoch 102/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6816e-05 - val_loss: 5.9593e-04
#
# Epoch 00102: val_loss did not improve from 0.00057
# Epoch 103/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3840e-05 - val_loss: 6.3016e-04
#
# Epoch 00103: val_loss did not improve from 0.00057
# Epoch 104/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6197e-05 - val_loss: 6.1048e-04
#
# Epoch 00104: val_loss did not improve from 0.00057
# Epoch 105/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2811e-05 - val_loss: 5.9671e-04
#
# Epoch 00105: val_loss did not improve from 0.00057
# Epoch 106/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.4187e-05 - val_loss: 6.1609e-04
#
# Epoch 00106: val_loss did not improve from 0.00057
# Epoch 107/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5124e-05 - val_loss: 6.2052e-04
#
# Epoch 00107: val_loss did not improve from 0.00057
# Epoch 108/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.4014e-05 - val_loss: 6.0071e-04
#
# Epoch 00108: val_loss did not improve from 0.00057
# Epoch 109/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2428e-05 - val_loss: 6.0204e-04
#
# Epoch 00109: val_loss did not improve from 0.00057
# Epoch 110/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3641e-05 - val_loss: 6.3775e-04
#
# Epoch 00110: val_loss did not improve from 0.00057
# Epoch 111/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3686e-05 - val_loss: 5.8465e-04
#
# Epoch 00111: val_loss did not improve from 0.00057
# Epoch 112/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1787e-05 - val_loss: 5.9347e-04
#
# Epoch 00112: val_loss did not improve from 0.00057
# Epoch 113/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2866e-05 - val_loss: 6.2078e-04
#
# Epoch 00113: val_loss did not improve from 0.00057
# Epoch 114/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1170e-05 - val_loss: 6.1877e-04
#
# Epoch 00114: val_loss did not improve from 0.00057
# Epoch 115/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9244e-05 - val_loss: 6.0390e-04
#
# Epoch 00115: val_loss did not improve from 0.00057
# Epoch 116/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2927e-05 - val_loss: 6.1106e-04
#
# Epoch 00116: val_loss did not improve from 0.00057
# Epoch 117/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9757e-05 - val_loss: 5.8800e-04
#
# Epoch 00117: val_loss did not improve from 0.00057
# Epoch 118/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8566e-05 - val_loss: 6.0114e-04
#
# Epoch 00118: val_loss did not improve from 0.00057
# Epoch 119/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8616e-05 - val_loss: 6.3823e-04
#
# Epoch 00119: val_loss did not improve from 0.00057
# Epoch 120/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8368e-05 - val_loss: 6.1707e-04
#
# Epoch 00120: val_loss did not improve from 0.00057
# Epoch 121/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1191e-05 - val_loss: 6.3678e-04
#
# Epoch 00121: val_loss did not improve from 0.00057
# Epoch 122/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.0376e-05 - val_loss: 5.9967e-04
#
# Epoch 00122: val_loss did not improve from 0.00057
# Epoch 123/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7873e-05 - val_loss: 6.1486e-04
#
# Epoch 00123: val_loss did not improve from 0.00057
# Epoch 124/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7615e-05 - val_loss: 6.0145e-04
#
# Epoch 00124: val_loss did not improve from 0.00057
# Epoch 125/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9327e-05 - val_loss: 6.2742e-04
#
# Epoch 00125: val_loss did not improve from 0.00057
# Epoch 126/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8338e-05 - val_loss: 6.1445e-04
#
# Epoch 00126: val_loss did not improve from 0.00057
# Epoch 127/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8635e-05 - val_loss: 5.9586e-04
#
# Epoch 00127: val_loss did not improve from 0.00057
# Epoch 128/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6316e-05 - val_loss: 6.1744e-04
#
# Epoch 00128: val_loss did not improve from 0.00057
# Epoch 129/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6478e-05 - val_loss: 6.2505e-04
#
# Epoch 00129: val_loss did not improve from 0.00057
# Epoch 130/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6564e-05 - val_loss: 6.1900e-04
#
# Epoch 00130: val_loss did not improve from 0.00057
# Epoch 131/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.4696e-05 - val_loss: 6.0780e-04
#
# Epoch 00131: val_loss did not improve from 0.00057
# Epoch 132/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6988e-05 - val_loss: 6.0663e-04
#
# Epoch 00132: val_loss did not improve from 0.00057
# Epoch 133/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7089e-05 - val_loss: 5.9895e-04
#
# Epoch 00133: val_loss did not improve from 0.00057
# Epoch 134/150
# 3424/3424 [==============================] - 29s 9ms/step - loss: 8.5033e-05 - val_loss: 6.0092e-04
#
# Epoch 00134: val_loss did not improve from 0.00057
# Epoch 135/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6350e-05 - val_loss: 6.0433e-04
#
# Epoch 00135: val_loss did not improve from 0.00057
# Epoch 136/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.4830e-05 - val_loss: 5.9618e-04
#
# Epoch 00136: val_loss did not improve from 0.00057
# Epoch 137/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3577e-05 - val_loss: 6.1557e-04
#
# Epoch 00137: val_loss did not improve from 0.00057
# Epoch 138/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7533e-05 - val_loss: 5.9373e-04
#
# Epoch 00138: val_loss did not improve from 0.00057
# Epoch 139/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3269e-05 - val_loss: 6.3203e-04
#
# Epoch 00139: val_loss did not improve from 0.00057
# Epoch 140/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3541e-05 - val_loss: 6.2364e-04
#
# Epoch 00140: val_loss did not improve from 0.00057
# Epoch 141/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3633e-05 - val_loss: 6.2131e-04
#
# Epoch 00141: val_loss did not improve from 0.00057
# Epoch 142/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5316e-05 - val_loss: 6.0197e-04
#
# Epoch 00142: val_loss did not improve from 0.00057
# Epoch 143/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6235e-05 - val_loss: 6.1450e-04
#
# Epoch 00143: val_loss did not improve from 0.00057
# Epoch 144/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.4342e-05 - val_loss: 6.1750e-04
#
# Epoch 00144: val_loss did not improve from 0.00057
# Epoch 145/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3726e-05 - val_loss: 6.1103e-04
#
# Epoch 00145: val_loss did not improve from 0.00057
# Epoch 146/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3631e-05 - val_loss: 6.2420e-04
#
# Epoch 00146: val_loss did not improve from 0.00057
# Epoch 147/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.2509e-05 - val_loss: 6.2004e-04
#
# Epoch 00147: val_loss did not improve from 0.00057
# Epoch 148/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1987e-05 - val_loss: 6.1966e-04
#
# Epoch 00148: val_loss did not improve from 0.00057
# Epoch 149/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1897e-05 - val_loss: 6.0793e-04
#
# Epoch 00149: val_loss did not improve from 0.00057
# Epoch 150/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1846e-05 - val_loss: 6.1501e-04
#
# Epoch 00150: val_loss did not improve from 0.00057

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
